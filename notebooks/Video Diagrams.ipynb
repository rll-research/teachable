# %%
from babyai.levels.iclr19_levels import *
from babyai.levels.teachable_robot_levels import Level_TeachableRobot
from minigrid import RoomGridLevel
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-41-314988eec663> in <module>
#       1 from babyai.levels.iclr19_levels import *
#       2 from babyai.levels.teachable_robot_levels import Level_TeachableRobot
# ----> 3 from minigrid import RoomGridLevel
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'minigrid'

# %%
env = Level_PutNext()
env.fully_observed = True
env.agent_view_size = 3

# %%
env.reset()
plt.rcParams['figure.figsize'] = [20,20]
plt.imshow(env.super().render('rgb_array'))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-17d19e13d774> in <module>
#       1 env.reset()
#       2 plt.rcParams['figure.figsize'] = [20,20]
# ----> 3 plt.imshow(env.super().render('rgb_array'))
#       4 plt.show()
#
# AttributeError: 'Level_PutNext' object has no attribute 'super'

# %%
plt.imshow(super(Level_TeachableRobot, env).render('rgb_array', highlight=False))
plt.axis('off')
plt.show()

# %%
env = Level_Unlock()
env.reset()
plt.rcParams['figure.figsize'] = [20,20]
plt.imshow(super(Level_TeachableRobot, env).render('rgb_array', highlight=False))
plt.axis('off')
plt.show()

# %%
super(Level_PutNext, env)
# Out:
# <super: babyai.levels.iclr19_levels.Level_PutNext,
#         <babyai.levels.iclr19_levels.Level_PutNext at 0x7f2d106df750>>
