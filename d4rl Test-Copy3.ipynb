# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np

# %%
import ray
from ray.rllib import agents
ray.init(log_to_driver=False) # Skip or set to ignore if already called

from envs.point_mass_env import PointMassEnv 
from ray.tune.logger import pretty_print
# Out:
# WARNING:tensorflow:From /home/olivia/anaconda3/envs/meta_mb/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2021-04-09 22:51:54,466	INFO services.py:1174 -- View the Ray dashboard at http://127.0.0.1:8268
# Warning: Flow failed to import. Set the environment variable D4RL_SUPPRESS_IMPORT_ERROR=1 to suppress this message.
# No module named 'flow'
# Warning: CARLA failed to import. Set the environment variable D4RL_SUPPRESS_IMPORT_ERROR=1 to suppress this message.
# No module named 'carla'

# %%
from ray.tune.registry import register_env

def env_creator(env_config):
    return PointMassEnv('maze2d-open-dense-v0')

register_env("point_mass_1", env_creator)

# %%
from ray.rllib.agents.callbacks import DefaultCallbacks

class CustomCallbacks(DefaultCallbacks):
    def on_episode_end(self, worker, base_env,
                       policies, episode,
                       **kwargs):
        success = int(episode.last_info_for()['success'])
        last_obs = episode.last_observation_for()
        pos = last_obs[:2]
        target = last_obs[4:6]
        dist = np.linalg.norm(pos - target)
        episode.custom_metrics['dist'] = dist
        episode.custom_metrics["success"] = success

# %% [markdown]
# ## Their Model

# %%
config = {
          'num_workers': 1,
          'train_batch_size': 1000,
          'log_level': 'ERROR',
          'framework': 'torch',
          'callbacks': CustomCallbacks,
          'model': {
              'fcnet_hiddens': [128, 128],
          }}
trainer = agents.ppo.PPOTrainer(env='point_mass_1', config=config)
for i in range(1000):
    results = trainer.train()
    print(f"episode {i}, mean rew {results['episode_reward_mean']}," +
          f"success_mean {results['custom_metrics']['success_mean']}, dist {results['custom_metrics']['dist_mean']}")
# Out:
# ---------------------------------------------------------------------------
# RaySystemError                            Traceback (most recent call last)
# <ipython-input-5-22d953e05d16> in <module>
#       8               'fcnet_hiddens': [128, 128],
#       9           }}
# ---> 10 trainer = agents.ppo.PPOTrainer(env='point_mass_1', config=config)
#      11 for i in range(1000):
#      12     results = trainer.train()
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/rllib/agents/trainer_template.py in __init__(self, config, env, logger_creator)
#     105
#     106         def __init__(self, config=None, env=None, logger_creator=None):
# --> 107             Trainer.__init__(self, config, env, logger_creator)
#     108
#     109         def _init(self, config: TrainerConfigDict,
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/rllib/agents/trainer.py in __init__(self, config, env, logger_creator)
#     484             logger_creator = default_logger_creator
#     485
# --> 486         super().__init__(config, logger_creator)
#     487
#     488     @classmethod
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/tune/trainable.py in __init__(self, config, logger_creator)
#      95
#      96         start_time = time.time()
# ---> 97         self.setup(copy.deepcopy(self.config))
#      98         setup_time = time.time() - start_time
#      99         if setup_time > SETUP_TIME_THRESHOLD:
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/rllib/agents/trainer.py in setup(self, config)
#     652
#     653         with get_scope():
# --> 654             self._init(self.config, self.env_creator)
#     655
#     656             # Evaluation setup.
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/rllib/agents/trainer_template.py in _init(self, config, env_creator)
#     137                 policy_class=self._policy_class,
#     138                 config=config,
# --> 139                 num_workers=self.config["num_workers"])
#     140             self.execution_plan = execution_plan
#     141             self.train_exec_impl = execution_plan(self.workers, config)
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/rllib/agents/trainer.py in _make_workers(self, env_creator, validate_env, policy_class, config, num_workers)
#     729             trainer_config=config,
#     730             num_workers=num_workers,
# --> 731             logdir=self.logdir)
#     732
#     733     @DeveloperAPI
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/rllib/evaluation/worker_set.py in __init__(self, env_creator, validate_env, policy_class, trainer_config, num_workers, logdir, _setup)
#      72             # Create a number of remote workers.
#      73             self._remote_workers = []
# ---> 74             self.add_workers(num_workers)
#      75
#      76             # If num_workers > 0, get the action_spaces and observation_spaces
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/rllib/evaluation/worker_set.py in add_workers(self, num_workers)
#     139                 worker_index=i + 1,
#     140                 num_workers=num_workers,
# --> 141                 config=self._remote_config) for i in range(num_workers)
#     142         ])
#     143
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/rllib/evaluation/worker_set.py in <listcomp>(.0)
#     139                 worker_index=i + 1,
#     140                 num_workers=num_workers,
# --> 141                 config=self._remote_config) for i in range(num_workers)
#     142         ])
#     143
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/rllib/evaluation/worker_set.py in _make_worker(self, cls, env_creator, validate_env, policy_cls, worker_index, num_workers, config, spaces)
#     360             extra_python_environs=extra_python_environs,
#     361             spaces=spaces,
# --> 362             _use_trajectory_view_api=config["_use_trajectory_view_api"],
#     363         )
#     364
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/actor.py in remote(self, *args, **kwargs)
#     408             A handle to the newly created actor.
#     409         """
# --> 410         return self._remote(args=args, kwargs=kwargs)
#     411
#     412     def options(self,
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/actor.py in _remote(self, args, kwargs, num_cpus, num_gpus, memory, object_store_memory, resources, accelerator_type, max_concurrency, max_restarts, max_task_retries, name, lifetime, placement_group, placement_group_bundle_index, placement_group_capture_child_tasks, override_environment_variables)
#     555
#     556         worker = ray.worker.global_worker
# --> 557         worker.check_connected()
#     558
#     559         if name is not None:
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/worker.py in check_connected(self)
#     205         """
#     206         if not self.connected:
# --> 207             raise RaySystemError("Ray has not been started yet. You can "
#     208                                  "start Ray with 'ray.init()'.")
#     209
#
# RaySystemError: System error: Ray has not been started yet. You can start Ray with 'ray.init()'.

# %% [markdown]
# # Our Model

# %%
config = {
          'num_workers': 1,
          'train_batch_size': 200,
          'log_level': 'ERROR',
          'framework': 'torch',
          'callbacks': CustomCallbacks,
              'lambda': .99,
              'num_sgd_iter': 4,
              'lr': 1e-5,
              'vf_loss_coeff': .05,
              'entropy_coeff': .01,
              'clip_param': .2,
              'vf_clip_param': .2,
              'grad_clip': .5,
          'model': {
              'fcnet_hiddens': [64, 64],
          }}
trainer = agents.ppo.PPOTrainer(env='point_mass_1', config=config)
for i in range(1000):
    results = trainer.train()
    print(f"episode {i}, mean rew {results['episode_reward_mean']}," +
          f"success_mean {results['custom_metrics']['success_mean']}, dist {results['custom_metrics']['dist_mean']}")
# Out:
# 2021-04-09 22:35:54,862	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# episode 0, mean rew 1.0692866670458385,success_mean 0.0, dist 1.9715892846976069
# episode 1, mean rew 0.8894788660171702,success_mean 0.0, dist 1.7873492818147683
# episode 2, mean rew 0.7707202149347199,success_mean 0.0, dist 1.747219061249293
# episode 3, mean rew 1.4870071118250645,success_mean 0.0, dist 1.6146722070907749
# episode 4, mean rew 1.4751989947015547,success_mean 0.0, dist 1.6230163641327033
# episode 5, mean rew 1.3336213128305683,success_mean 0.0, dist 1.5965751981046032
# episode 6, mean rew 1.216758760241136,success_mean 0.0, dist 1.6749183910915009
# episode 7, mean rew 1.1032890394815946,success_mean 0.0, dist 1.6637052698397556
# episode 8, mean rew 1.0496191374475825,success_mean 0.0, dist 1.6709231376646045
# episode 9, mean rew 1.100692563938615,success_mean 0.0, dist 1.6377839572556991
# episode 10, mean rew 1.0230912662509597,success_mean 0.0, dist 1.6849154009430667
# episode 11, mean rew 1.0660560557408691,success_mean 0.0, dist 1.6120337411991557
# episode 12, mean rew 1.0021282618122556,success_mean 0.0, dist 1.6307354956759192
# episode 13, mean rew 0.9619388072099768,success_mean 0.0, dist 1.639360284377127
# episode 14, mean rew 0.9312016253317704,success_mean 0.0, dist 1.6330271732610835
# episode 15, mean rew 0.8960088000719867,success_mean 0.0, dist 1.6561848885709551
# episode 16, mean rew 0.873954690170205,success_mean 0.0, dist 1.6830555723589422
# episode 17, mean rew 0.8651408716797319,success_mean 0.0, dist 1.6658951727752622
# episode 18, mean rew 0.9042125484114135,success_mean 0.0, dist 1.6429277577431745
# episode 19, mean rew 0.8769201099487375,success_mean 0.0, dist 1.6630968822222827
# episode 20, mean rew 0.8468857963576694,success_mean 0.0, dist 1.646967263165236
# episode 21, mean rew 0.8905741970356975,success_mean 0.0, dist 1.6266310122708485
# episode 22, mean rew 0.8629858631482884,success_mean 0.0, dist 1.6445161744512933
# episode 23, mean rew 0.8095421914129948,success_mean 0.0, dist 1.678276071972384
# episode 24, mean rew 0.783811093236022,success_mean 0.0, dist 1.685298050197106
# episode 25, mean rew 0.7910411153195688,success_mean 0.0, dist 1.6677518066249684
# episode 26, mean rew 0.8873094286371237,success_mean 0.0, dist 1.6434642399532382
# episode 27, mean rew 0.9085337442533046,success_mean 0.0, dist 1.628914938082609
# episode 28, mean rew 0.9162033101642029,success_mean 0.0, dist 1.6177998761089714
# episode 332, mean rew 1.7952213052716968,success_mean 0.0, dist 2.415208741269231
# episode 333, mean rew 1.7972075779741277,success_mean 0.0, dist 2.4093624854159588
# episode 334, mean rew 1.8103508111047422,success_mean 0.0, dist 2.4112955894524855
# episode 335, mean rew 1.8101012043701337,success_mean 0.0, dist 2.3939498222403377
# episode 336, mean rew 1.814482414851238,success_mean 0.0, dist 2.4048384016440174
# episode 337, mean rew 1.8210371076307412,success_mean 0.0, dist 2.40956285045902
# episode 338, mean rew 1.8016668820903194,success_mean 0.0, dist 2.42972482866654
# episode 339, mean rew 1.7980230619965303,success_mean 0.0, dist 2.4365806160648535
# episode 340, mean rew 1.8074931025452403,success_mean 0.0, dist 2.4367877500513013
# episode 341, mean rew 1.8068265515047823,success_mean 0.0, dist 2.421365049578034
# episode 342, mean rew 1.821078116033253,success_mean 0.0, dist 2.422444525925277
# episode 343, mean rew 1.8302313894100846,success_mean 0.0, dist 2.417718071874097
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-c8ec6f11c112> in <module>
#      18 trainer = agents.ppo.PPOTrainer(env='point_mass_1', config=config)
#      19 for i in range(1000):
# ---> 20     results = trainer.train()
#      21     print(f"episode {i}, mean rew {results['episode_reward_mean']}," +
#      22           f"success_mean {results['custom_metrics']['success_mean']}, dist {results['custom_metrics']['dist_mean']}")
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/rllib/agents/trainer.py in train(self)
#     513         for _ in range(1 + MAX_WORKER_FAILURE_RETRIES):
#     514             try:
# --> 515                 result = Trainable.train(self)
#     516             except RayError as e:
#     517                 if self.config["ignore_worker_failures"]:
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/tune/trainable.py in train(self)
#     224         """
#     225         start = time.time()
# --> 226         result = self.step()
#     227         assert isinstance(result, dict), "step() needs to return a dict."
#     228
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/rllib/agents/trainer_template.py in step(self)
#     146         @override(Trainer)
#     147         def step(self):
# --> 148             res = next(self.train_exec_impl)
#     149
#     150             # self._iteration gets incremented after this function returns,
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in __next__(self)
#     754     def __next__(self):
#     755         self._build_once()
# --> 756         return next(self.built_iterator)
#     757
#     758     def __str__(self):
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_filter(it)
#     841     def filter(self, fn: Callable[[T], bool]) -> "LocalIterator[T]":
#     842         def apply_filter(it):
# --> 843             for item in it:
#     844                 with self._metrics_context():
#     845                     if isinstance(item, _NextValueNotReady) or fn(item):
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_filter(it)
#     841     def filter(self, fn: Callable[[T], bool]) -> "LocalIterator[T]":
#     842         def apply_filter(it):
# --> 843             for item in it:
#     844                 with self._metrics_context():
#     845                     if isinstance(item, _NextValueNotReady) or fn(item):
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_flatten(it)
#     874     def flatten(self) -> "LocalIterator[T[0]]":
#     875         def apply_flatten(it):
# --> 876             for item in it:
#     877                 if isinstance(item, _NextValueNotReady):
#     878                     yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in add_wait_hooks(it)
#     826                             fn._on_fetch_start()
#     827                         new_item = False
# --> 828                     item = next(it)
#     829                     if not isinstance(item, _NextValueNotReady):
#     830                         new_item = True
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in base_iterator(timeout)
#     469             while active:
#     470                 try:
# --> 471                     yield ray.get(futures, timeout=timeout)
#     472                     futures = [a.par_iter_next.remote() for a in active]
#     473                     # Always yield after each round of gets with timeout.
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/_private/client_mode_hook.py in wrapper(*args, **kwargs)
#      45         if client_mode_enabled and _client_hook_enabled:
#      46             return getattr(ray, func.__name__)(*args, **kwargs)
# ---> 47         return func(*args, **kwargs)
#      48
#      49     return wrapper
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/worker.py in get(object_refs, timeout)
#    1447         # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
#    1448         values, debugger_breakpoint = worker.get_objects(
# -> 1449             object_refs, timeout=timeout)
#    1450         for i, value in enumerate(values):
#    1451             if isinstance(value, RayError):
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/worker.py in get_objects(self, object_refs, timeout)
#     308         timeout_ms = int(timeout * 1000) if timeout else -1
#     309         data_metadata_pairs = self.core_worker.get_objects(
# --> 310             object_refs, self.current_task_id, timeout_ms)
#     311         debugger_breakpoint = b""
#     312         for (data, metadata) in data_metadata_pairs:
#
# KeyboardInterrupt:

# %% [markdown]
# # Our Model, their Hparams

# %%
config = {
          'num_workers': 1,
          'log_level': 'ERROR',
          'framework': 'torch',
          'callbacks': CustomCallbacks,
             'train_batch_size': 1000,
#               'lambda': .99,
#               'num_sgd_iter': 4,
#               'lr': 1e-5,
#               'vf_loss_coeff': .05,
#               'entropy_coeff': .01,
#               'clip_param': .2,
#               'vf_clip_param': .2,
#               'grad_clip': .5,
          'model': {
              'fcnet_hiddens': [64, 64],
          }}
trainer = agents.ppo.PPOTrainer(env='point_mass_1', config=config)
for i in range(1000):
    results = trainer.train()
    print(f"episode {i}, mean rew {results['episode_reward_mean']}," +
          f"success_mean {results['custom_metrics']['success_mean']}, dist {results['custom_metrics']['dist_mean']}")
# Out:
# 2021-04-09 22:39:35,273	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# episode 0, mean rew 0.6130870731157936,success_mean 0.0, dist 1.5921449389108202
# episode 1, mean rew 1.2603985894650935,success_mean 0.0, dist 1.3978968519769315
# episode 2, mean rew 1.6397175687765189,success_mean 0.0, dist 1.2829645914351056
# episode 3, mean rew 1.8413079892639617,success_mean 0.0, dist 1.270840889907793
# episode 4, mean rew 2.156830142168495,success_mean 0.0, dist 1.2729382458015874
# episode 5, mean rew 2.3076811655311666,success_mean 0.0, dist 1.4099414971591138
# episode 6, mean rew 2.4904063874259212,success_mean 0.0, dist 1.462403880433009
# episode 7, mean rew 2.6058275301371445,success_mean 0.0, dist 1.5258415119505744
# episode 8, mean rew 2.7845356533821137,success_mean 0.0, dist 1.5302406507837254
# episode 9, mean rew 2.9226877111560543,success_mean 0.0, dist 1.509508168439038
# episode 10, mean rew 3.0721563019944016,success_mean 0.0, dist 1.5143305709169286
# episode 11, mean rew 3.2288280920816184,success_mean 0.0, dist 1.5142189454024064
# episode 12, mean rew 3.361162435700598,success_mean 0.0, dist 1.4990753097683933
# episode 13, mean rew 3.496664479728543,success_mean 0.0, dist 1.4761274133504978
# episode 14, mean rew 3.5933977808889357,success_mean 0.0, dist 1.4489168821168772
# episode 15, mean rew 3.87705700103066,success_mean 0.0, dist 1.418279233232679
# episode 16, mean rew 4.111975266908634,success_mean 0.0, dist 1.4123662215939066
# episode 17, mean rew 4.347036972639777,success_mean 0.0, dist 1.4083165718830841
# episode 18, mean rew 4.538147053502399,success_mean 0.0, dist 1.3923135105886737
# episode 19, mean rew 4.687471383078764,success_mean 0.0, dist 1.373338390416316
# episode 20, mean rew 4.873770198621725,success_mean 0.0, dist 1.2971211262936324
# episode 21, mean rew 5.007769783953926,success_mean 0.0, dist 1.2428854542113676
# episode 22, mean rew 5.211924806524166,success_mean 0.0, dist 1.1607914304475775
# episode 23, mean rew 5.365549115530366,success_mean 0.0, dist 1.1023816788125236
# episode 24, mean rew 5.496294331587676,success_mean 0.0, dist 1.0614458683318901
# episode 25, mean rew 5.637980650531249,success_mean 0.0, dist 0.9948683911786473
# episode 26, mean rew 5.770074338127739,success_mean 0.0, dist 0.9278793058435444
# episode 27, mean rew 5.871350934533751,success_mean 0.0, dist 0.8822997045440424
# episode 28, mean rew 5.990073171677986,success_mean 0.0, dist 0.8334990892851595
# episode 29, mean rew 6.153275371527614,success_mean 0.0, dist 0.7868946438042984

# %% [markdown]
# # Their Model, our HParams

# %%
config = {
          'num_workers': 1,
          'train_batch_size': 200,
          'log_level': 'ERROR',
          'framework': 'torch',
          'callbacks': CustomCallbacks,
              'lambda': .99,
              'num_sgd_iter': 4,
              'lr': 1e-5,
              'vf_loss_coeff': .05,
              'entropy_coeff': .01,
              'clip_param': .2,
              'vf_clip_param': .2,
              'grad_clip': .5,
          'model': {
              'fcnet_hiddens': [128, 128],
          }}
trainer = agents.ppo.PPOTrainer(env='point_mass_1', config=config)
for i in range(1000):
    results = trainer.train()
    print(f"episode {i}, mean rew {results['episode_reward_mean']}," +
          f"success_mean {results['custom_metrics']['success_mean']}, dist {results['custom_metrics']['dist_mean']}")
# Out:
# 2021-04-09 22:43:54,709	INFO trainer.py:643 -- Current log_level is ERROR. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2021-04-09 22:44:00,725	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# episode 0, mean rew -0.0042672618553116475,success_mean 0.0, dist 2.1171825753317055
# episode 1, mean rew 1.5317670709560858,success_mean 0.0, dist 2.1168891402773533
# episode 2, mean rew 0.9739439059429491,success_mean 0.0, dist 1.9867344200294526
# episode 3, mean rew 0.8237294325591751,success_mean 0.0, dist 1.8542234287824317
# episode 4, mean rew 0.7392553537863841,success_mean 0.0, dist 1.9621321681932928
# episode 5, mean rew 0.6879680612319949,success_mean 0.0, dist 1.8686331072202176
# episode 6, mean rew 0.6471540448907273,success_mean 0.0, dist 1.8828189734036525
# episode 7, mean rew 0.6223198834984571,success_mean 0.0, dist 1.9148429112651197
# episode 8, mean rew 0.5609702963733796,success_mean 0.0, dist 1.9498221809292697
# episode 9, mean rew 0.5457376445191924,success_mean 0.0, dist 1.9496464271918301
# episode 10, mean rew 0.5276753572721965,success_mean 0.0, dist 1.9644001709102592
# episode 467, mean rew 3.590097859245652,success_mean 0.0, dist 1.3829777042486566

# %% [markdown]
# # HParam Sweep

# %%
config = { # THEIRS: train_batch_size, num_sgd_iter, lr, entropy
          'num_workers': 1,
          'log_level': 'ERROR',
          'framework': 'torch',
          'callbacks': CustomCallbacks,
          'train_batch_size': 1000,
              'lambda': .99,
#               'num_sgd_iter': 4,
#               'lr': 1e-5,
              'vf_loss_coeff': .05,
#               'entropy_coeff': .01,
#               'clip_param': .2,
#               'vf_clip_param': .2,
              'grad_clip': .5,
          'model': {
              'fcnet_hiddens': [128, 128],
          }}
trainer = agents.ppo.PPOTrainer(env='point_mass_1', config=config)
for i in range(1000):
    results = trainer.train()
    print(f"episode {i}, mean rew {results['episode_reward_mean']}," +
          f"success_mean {results['custom_metrics']['success_mean']}, dist {results['custom_metrics']['dist_mean']}")
# Out:
# 2021-04-09 23:10:46,887	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# episode 0, mean rew 0.6936445512157147,success_mean 0.0, dist 1.5130763623598125
# episode 1, mean rew 1.180317509282308,success_mean 0.0, dist 1.3928303533079698
# episode 2, mean rew 1.5209233748379507,success_mean 0.0, dist 1.4111612057029457
# episode 3, mean rew 2.0358760571766514,success_mean 0.0, dist 1.4332206199709197
# episode 4, mean rew 2.409555216153366,success_mean 0.0, dist 1.407999173847923
# episode 5, mean rew 2.713123403655735,success_mean 0.0, dist 1.4516784846771074
# episode 6, mean rew 2.9830066569648244,success_mean 0.0, dist 1.4131335758919696
# episode 7, mean rew 3.271533921816679,success_mean 0.0, dist 1.3680228569363557
# episode 8, mean rew 3.4457980651898565,success_mean 0.0, dist 1.3529607477770382
# episode 9, mean rew 3.575116924405371,success_mean 0.0, dist 1.3430542497183464
# episode 10, mean rew 3.717299983807245,success_mean 0.0, dist 1.3322161155898171
# episode 11, mean rew 3.834955948554685,success_mean 0.0, dist 1.321343120642565
# episode 12, mean rew 3.9352369976271575,success_mean 0.0, dist 1.313430594071886
# episode 13, mean rew 4.0599947416813205,success_mean 0.0, dist 1.2932476618426008
# episode 14, mean rew 4.170544767219813,success_mean 0.0, dist 1.27772301824588
# episode 15, mean rew 4.482023611937798,success_mean 0.0, dist 1.2456357394079551
# episode 16, mean rew 4.781599908636719,success_mean 0.0, dist 1.222375849535441
# episode 17, mean rew 5.0669544438533425,success_mean 0.0, dist 1.1785916742718408
# episode 18, mean rew 5.243281741724692,success_mean 0.0, dist 1.1272044386803892
# episode 19, mean rew 5.441083412740104,success_mean 0.0, dist 1.0822438945885104
# episode 20, mean rew 5.642215086418656,success_mean 0.0, dist 1.000259925671442
# episode 21, mean rew 5.7858249010759994,success_mean 0.0, dist 0.9590661339908977
# episode 22, mean rew 5.939910591853906,success_mean 0.0, dist 0.9100091900793936
# episode 23, mean rew 6.12896063903031,success_mean 0.0, dist 0.8508229510638177
# episode 24, mean rew 6.282536252664766,success_mean 0.0, dist 0.8015386176342071
# episode 25, mean rew 6.466949083379649,success_mean 0.0, dist 0.7355933146146916
# episode 64, mean rew 6.741737696398546,success_mean 0.03, dist 0.2357587497745926
# episode 65, mean rew 6.754773725004209,success_mean 0.06, dist 0.2244347558419472
# episode 66, mean rew 6.738157124402902,success_mean 0.06, dist 0.2245581070407117
# episode 67, mean rew 6.737054541843978,success_mean 0.06, dist 0.2179173546402324
# episode 68, mean rew 6.695972568452548,success_mean 0.05, dist 0.22376100268375876
# episode 69, mean rew 6.665705085254532,success_mean 0.05, dist 0.22580551230256143
# episode 70, mean rew 6.636367519106277,success_mean 0.04, dist 0.22806608996481592
# episode 71, mean rew 6.579902360097992,success_mean 0.03, dist 0.23494137929548553
# episode 72, mean rew 6.573427476902778,success_mean 0.03, dist 0.23077113226364904
# episode 73, mean rew 6.555624101964969,success_mean 0.03, dist 0.22703993855428803
# episode 74, mean rew 6.538590726109487,success_mean 0.03, dist 0.22313659731435442
# episode 75, mean rew 6.524553168399945,success_mean 0.03, dist 0.22172698500530796
# episode 76, mean rew 6.501137663488581,success_mean 0.03, dist 0.22174406230401206
# episode 77, mean rew 6.481707749391531,success_mean 0.03, dist 0.22238804062659956
# episode 78, mean rew 6.460611129508347,success_mean 0.03, dist 0.2266851882824654
# episode 79, mean rew 6.420873774130957,success_mean 0.03, dist 0.2361697822965831
# episode 80, mean rew 6.369277563495618,success_mean 0.0, dist 0.2487076149196544
# episode 81, mean rew 6.347964443447626,success_mean 0.0, dist 0.2528090205375478
# episode 82, mean rew 6.325672840829192,success_mean 0.0, dist 0.26026353143077174
# episode 83, mean rew 6.308551867940146,success_mean 0.0, dist 0.26152778982312413
# episode 84, mean rew 6.276093617369722,success_mean 0.0, dist 0.27442756681287
# episode 85, mean rew 6.241999680654873,success_mean 0.0, dist 0.2869318437036948
# episode 86, mean rew 6.224847138630247,success_mean 0.0, dist 0.29616425658652856
# episode 87, mean rew 6.199493369882106,success_mean 0.0, dist 0.3045076652835348
# episode 88, mean rew 6.1878282940599885,success_mean 0.0, dist 0.3113499450017649
# episode 89, mean rew 6.15074416550486,success_mean 0.0, dist 0.326675366728071
# episode 90, mean rew 6.146703124312488,success_mean 0.0, dist 0.32979705788124575
# episode 91, mean rew 6.158403473411588,success_mean 0.0, dist 0.3311088762849006
# episode 92, mean rew 6.171477133915269,success_mean 0.0, dist 0.33024187231360963
# episode 93, mean rew 6.176848913478004,success_mean 0.0, dist 0.33303730347184496
# episode 94, mean rew 6.200357525001608,success_mean 0.0, dist 0.33167336452553164
# episode 95, mean rew 6.222434633581648,success_mean 0.0, dist 0.3277815962105909
# episode 96, mean rew 6.233285794997308,success_mean 0.0, dist 0.33038854422769554
# episode 97, mean rew 6.218164573071281,success_mean 0.0, dist 0.34132643025275555
# episode 98, mean rew 6.22807726635533,success_mean 0.0, dist 0.3423188954967331
# episode 99, mean rew 6.256426612292305,success_mean 0.0, dist 0.33527979604408675
# episode 100, mean rew 6.283140301138528,success_mean 0.01, dist 0.32670394153713206
# episode 101, mean rew 6.301915209821405,success_mean 0.01, dist 0.3208584799708498
# episode 102, mean rew 6.321233479409588,success_mean 0.01, dist 0.3139016550779648
# episode 103, mean rew 6.379942715057857,success_mean 0.04, dist 0.3006784223139882
# episode 104, mean rew 6.434317165654787,success_mean 0.06, dist 0.2855488231172446
# episode 105, mean rew 6.45468644485481,success_mean 0.06, dist 0.2791311509505089
# episode 106, mean rew 6.45942274431593,success_mean 0.06, dist 0.2772138395620911
# episode 107, mean rew 6.461741179758622,success_mean 0.06, dist 0.2748486412990433
# episode 108, mean rew 6.460803853043865,success_mean 0.06, dist 0.27000392181987914
# episode 109, mean rew 6.476869853697382,success_mean 0.06, dist 0.26433501895308603
# episode 110, mean rew 6.49896129800594,success_mean 0.06, dist 0.25982152438935324
# episode 111, mean rew 6.494985100541798,success_mean 0.06, dist 0.25508812174388673
# episode 112, mean rew 6.50308814859464,success_mean 0.06, dist 0.24300830930853454
# episode 113, mean rew 6.482520928641164,success_mean 0.06, dist 0.24320978019762562
# episode 114, mean rew 6.468482852089946,success_mean 0.06, dist 0.24248079724360835
# episode 115, mean rew 6.456096248385653,success_mean 0.05, dist 0.24395288770802614
# episode 116, mean rew 6.42733416556398,success_mean 0.05, dist 0.2471892637962306
# episode 117, mean rew 6.393685999820982,success_mean 0.05, dist 0.2539348017283504
# episode 118, mean rew 6.300549110953937,success_mean 0.02, dist 0.273448403779769
# episode 119, mean rew 6.243242800497142,success_mean 0.0, dist 0.2858825473246416
# episode 120, mean rew 6.191844571743038,success_mean 0.0, dist 0.2985564247579045
# episode 121, mean rew 6.161967981321056,success_mean 0.0, dist 0.3027197533466321
# episode 122, mean rew 6.125410334768072,success_mean 0.0, dist 0.31171188374708786
# episode 123, mean rew 6.111231676438463,success_mean 0.0, dist 0.31247114331945336
# episode 124, mean rew 6.087483467104087,success_mean 0.0, dist 0.3113745181908987
# episode 125, mean rew 6.06217637756601,success_mean 0.0, dist 0.309916205271381
# episode 126, mean rew 6.070682567717478,success_mean 0.0, dist 0.3064405603258786
# episode 127, mean rew 6.06356499020096,success_mean 0.0, dist 0.3061239499107203
# episode 128, mean rew 6.056238156355157,success_mean 0.0, dist 0.30460963330360785
# episode 129, mean rew 6.054995688496636,success_mean 0.01, dist 0.3028899112427817
# episode 130, mean rew 6.033656978384747,success_mean 0.01, dist 0.3037044000536092
# episode 131, mean rew 6.034328469645309,success_mean 0.01, dist 0.3017303197794518
# episode 132, mean rew 6.023347231328857,success_mean 0.01, dist 0.30095621578897536
# episode 133, mean rew 6.013778979740255,success_mean 0.01, dist 0.2974282296129618
# episode 134, mean rew 5.968883877613093,success_mean 0.01, dist 0.3009964030294441
# episode 135, mean rew 5.9347136224838035,success_mean 0.01, dist 0.30693358763004364
# episode 136, mean rew 5.883123789263931,success_mean 0.01, dist 0.31905429195091034
# episode 137, mean rew 5.821644482522502,success_mean 0.01, dist 0.3338070953900227
# episode 138, mean rew 5.7484973673191675,success_mean 0.01, dist 0.3498193811390255
# episode 139, mean rew 5.66969342468289,success_mean 0.01, dist 0.37242782216716436
# episode 140, mean rew 5.5822748515112846,success_mean 0.01, dist 0.4003822213807728
# episode 218, mean rew 5.371880459037088,success_mean 0.0, dist 0.5080120698266217
# episode 219, mean rew 5.367382205546029,success_mean 0.0, dist 0.5098070406185805
# episode 220, mean rew 5.3635731737596215,success_mean 0.0, dist 0.5072950987471977
# episode 221, mean rew 5.35809355909004,success_mean 0.0, dist 0.5082912880965774
# episode 222, mean rew 5.350353487302333,success_mean 0.0, dist 0.5099122942269364
# episode 223, mean rew 5.334354106364333,success_mean 0.0, dist 0.5161787592015127
# episode 224, mean rew 5.317608712669447,success_mean 0.0, dist 0.5212579736441151
# episode 225, mean rew 5.299805454169943,success_mean 0.0, dist 0.5275260585842717
# episode 226, mean rew 5.283907569696122,success_mean 0.0, dist 0.5326852662796087
# episode 227, mean rew 5.268759992639418,success_mean 0.0, dist 0.5384024839890418
# episode 228, mean rew 5.253510543157805,success_mean 0.0, dist 0.5416624946997138
# episode 229, mean rew 5.2377976080823885,success_mean 0.0, dist 0.5455256938897493
# episode 230, mean rew 5.216592221674303,success_mean 0.0, dist 0.5518045099692052
# ---------------------------------------------------------------------------
# RayTaskError(RayOutOfMemoryError)         Traceback (most recent call last)
# <ipython-input-8-ca173449df41> in <module>
#      18 trainer = agents.ppo.PPOTrainer(env='point_mass_1', config=config)
#      19 for i in range(1000):
# ---> 20     results = trainer.train()
#      21     print(f"episode {i}, mean rew {results['episode_reward_mean']}," +
#      22           f"success_mean {results['custom_metrics']['success_mean']}, dist {results['custom_metrics']['dist_mean']}")
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/rllib/agents/trainer.py in train(self)
#     524                         "continue training without the failed worker, set "
#     525                         "`'ignore_worker_failures': True`.")
# --> 526                     raise e
#     527             except Exception as e:
#     528                 time.sleep(0.5)  # allow logs messages to propagate
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/rllib/agents/trainer.py in train(self)
#     513         for _ in range(1 + MAX_WORKER_FAILURE_RETRIES):
#     514             try:
# --> 515                 result = Trainable.train(self)
#     516             except RayError as e:
#     517                 if self.config["ignore_worker_failures"]:
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/tune/trainable.py in train(self)
#     224         """
#     225         start = time.time()
# --> 226         result = self.step()
#     227         assert isinstance(result, dict), "step() needs to return a dict."
#     228
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/rllib/agents/trainer_template.py in step(self)
#     146         @override(Trainer)
#     147         def step(self):
# --> 148             res = next(self.train_exec_impl)
#     149
#     150             # self._iteration gets incremented after this function returns,
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in __next__(self)
#     754     def __next__(self):
#     755         self._build_once()
# --> 756         return next(self.built_iterator)
#     757
#     758     def __str__(self):
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_filter(it)
#     841     def filter(self, fn: Callable[[T], bool]) -> "LocalIterator[T]":
#     842         def apply_filter(it):
# --> 843             for item in it:
#     844                 with self._metrics_context():
#     845                     if isinstance(item, _NextValueNotReady) or fn(item):
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_filter(it)
#     841     def filter(self, fn: Callable[[T], bool]) -> "LocalIterator[T]":
#     842         def apply_filter(it):
# --> 843             for item in it:
#     844                 with self._metrics_context():
#     845                     if isinstance(item, _NextValueNotReady) or fn(item):
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_flatten(it)
#     874     def flatten(self) -> "LocalIterator[T[0]]":
#     875         def apply_flatten(it):
# --> 876             for item in it:
#     877                 if isinstance(item, _NextValueNotReady):
#     878                     yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in add_wait_hooks(it)
#     826                             fn._on_fetch_start()
#     827                         new_item = False
# --> 828                     item = next(it)
#     829                     if not isinstance(item, _NextValueNotReady):
#     830                         new_item = True
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in apply_foreach(it)
#     781
#     782             def apply_foreach(it):
# --> 783                 for item in it:
#     784                     if isinstance(item, _NextValueNotReady):
#     785                         yield item
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/util/iter.py in base_iterator(timeout)
#     469             while active:
#     470                 try:
# --> 471                     yield ray.get(futures, timeout=timeout)
#     472                     futures = [a.par_iter_next.remote() for a in active]
#     473                     # Always yield after each round of gets with timeout.
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/_private/client_mode_hook.py in wrapper(*args, **kwargs)
#      45         if client_mode_enabled and _client_hook_enabled:
#      46             return getattr(ray, func.__name__)(*args, **kwargs)
# ---> 47         return func(*args, **kwargs)
#      48
#      49     return wrapper
#
# ~/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/worker.py in get(object_refs, timeout)
#    1454                     worker.core_worker.dump_object_store_memory_usage()
#    1455                 if isinstance(value, RayTaskError):
# -> 1456                     raise value.as_instanceof_cause()
#    1457                 else:
#    1458                     raise value
#
# RayTaskError(RayOutOfMemoryError): ray::RolloutWorker.par_iter_next() (pid=26788, ip=192.168.1.61)
#   File "python/ray/_raylet.pyx", line 440, in ray._raylet.execute_task
#   File "/home/olivia/anaconda3/envs/meta_mb/lib/python3.7/site-packages/ray/memory_monitor.py", line 132, in raise_if_low_memory
#     self.error_threshold))
# ray.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node ignasi-desktop is used (30.16 / 31.26 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 29346	4.1GiB	/home/olivia/anaconda3/envs/meta_mb/bin/python /opt/pycharm-community-2019.2.4/helpers/pydev/pydevd.
# 3194	2.55GiB	/usr/lib/x86_64-linux-gnu/hud/hud-service
# 29704	2.41GiB	/snap/pycharm-professional/240/jbr/bin/java -classpath /snap/pycharm-professional/240/lib/bootstrap.
# 27578	1.74GiB	/home/olivia/anaconda3/envs/meta_mb/bin/python -m ipykernel_launcher -f /home/olivia/.local/share/ju
# 25070	1.67GiB	/home/olivia/anaconda3/envs/meta_mb/bin/python -m ipykernel_launcher -f /home/olivia/.local/share/ju
# 25924	1.66GiB	/home/olivia/anaconda3/envs/meta_mb/bin/python -m ipykernel_launcher -f /home/olivia/.local/share/ju
# 26426	1.66GiB	/home/olivia/anaconda3/envs/meta_mb/bin/python -m ipykernel_launcher -f /home/olivia/.local/share/ju
# 4915	1.58GiB	/opt/pycharm-community-2019.2.4/jbr/bin/java -classpath /opt/pycharm-community-2019.2.4/lib/bootstra
# 3948	0.73GiB	/usr/lib/firefox/firefox -contentproc -childID 6 -isForBrowser -prefsLen 6965 -prefMapSize 195736 -p
# 3927	0.69GiB	/usr/lib/firefox/firefox -contentproc -childID 5 -isForBrowser -prefsLen 6965 -prefMapSize 195736 -p
#
# In addition, up to 0.65 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# ---
